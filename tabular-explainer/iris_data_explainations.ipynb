# %%
from sklearn import datasets

iris = datasets.load_iris()

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Load the iris dataset
iris = load_iris()
X, y = iris.data, iris.target
class_names = iris.target_names

# Normalize the iris data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

def Tabular_Mask(sample, n_samples=50):
    masks = np.tile(sample, (n_samples, 1))
    for i in range(n_samples):
        feature_to_change = np.random.randint(0, 4)  # Randomly select a feature to change
        min_val = X[:, feature_to_change].min()
        max_val = X[:, feature_to_change].max()
        masks[i, feature_to_change] = np.random.uniform(min_val, max_val)
    return masks

# Split the original (non-normalized) data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


clf = RandomForestClassifier(n_estimators=100, max_depth=None, min_samples_split=2, random_state=0)
clf.fit(X_train, y_train)


# Take one sample from X (let's use the first sample)
sample_original = X_test[0]
original_class = clf.predict([sample_original])[0]

def create_test_suit(sample, n_samples=100):
    correct_mutants = []
    incorrect_mutants = []
    
    while len(correct_mutants) < n_samples // 2 or len(incorrect_mutants) < n_samples // 2:
        masks = Tabular_Mask(sample, n_samples=10)  # Create 10 mutants at a time
        for mask in masks:
            predicted_class = clf.predict([mask])[0]
            if predicted_class == original_class and len(correct_mutants) < n_samples // 2:
                correct_mutants.append(mask)
            elif predicted_class != original_class and len(incorrect_mutants) < n_samples // 2:
                incorrect_mutants.append(mask)
    
    Test_Suit = np.vstack((correct_mutants[:n_samples//2], incorrect_mutants[:n_samples//2]))
    np.random.shuffle(Test_Suit)  # Shuffle the Test_Suit
    return Test_Suit

# Create the Test_Suit
Test_Suit = create_test_suit(sample_original)

# Print the original sample and its predicted class
print("Original sample:")
print(sample_original)
print(f"Predicted class for original sample: {original_class} ({class_names[original_class]})")

print("\nTest_Suit mutants and their predictions:")
for i, mutant in enumerate(Test_Suit):
    print(f"Mutant {i}:")
    print(mutant)
    predicted_class = clf.predict([mutant])[0]
    print(f"Predicted class: {predicted_class} ({class_names[predicted_class]})")
    print(f"Changed feature: {np.where(mutant != sample_original)[0][0]}")
    print(f"Correctly classified: {predicted_class == original_class}")
    print()

# Count the occurrences of each predicted class in Test_Suit
test_suit_predictions = clf.predict(Test_Suit)
unique, counts = np.unique(test_suit_predictions, return_counts=True)
print("\nPrediction distribution for Test_Suit:")
for class_label, count in zip(unique, counts):
    print(f"Class {class_label} ({class_names[class_label]}): {count} mutants")

# Verify the balance of Test_Suit
correct_count = sum(clf.predict(Test_Suit) == original_class)
print(f"\nCorrectly classified mutants in Test_Suit: {correct_count}")
print(f"Incorrectly classified mutants in Test_Suit: {len(Test_Suit) - correct_count}")

# Print class name mapping for reference
print("\nClass name mapping:")
for i, name in enumerate(class_names):
    print(f"Class {i}: {name}")

# Print feature names for reference
print("\nFeature names:")
for i, name in enumerate(iris.feature_names):
    print(f"Feature {i}: {name}")
# Out:
# Original sample:
# [6.1 2.8 4.7 1.2]
# Predicted class for original sample: 1 (versicolor)
#
# Test_Suit mutants and their predictions:
# Mutant 0:
# [6.1        2.8        1.00027871 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 1:
# [5.31952993 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 2:
# [6.1        2.8        4.7        1.87623019]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 3:
# [6.1       2.8       4.7       2.0131531]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 4:
# [6.1        2.8        6.40354545 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 5:
# [6.1        2.8        4.7        1.38654995]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 6:
# [6.1        2.8        4.7        0.89654725]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 7:
# [6.1        2.8        6.66355513 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 8:
# [6.80388916 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 9:
# [6.1        2.8        4.39625505 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 10:
# [6.1        2.8        1.05852053 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 11:
# [6.1       2.8       2.4480692 1.2      ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 12:
# [6.1        4.30735852 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 13:
# [6.1        2.41562567 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 14:
# [6.1        2.8        6.04718812 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 15:
# [6.1        3.52293197 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 16:
# [6.1        2.8        2.90259833 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 17:
# [6.49820507 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 18:
# [6.1       2.8       4.7       0.3701724]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 19:
# [6.1        2.8        5.46476767 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 20:
# [6.1        2.8        4.7        2.34859173]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 21:
# [6.1        2.8        4.7        2.37689862]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 22:
# [6.1        2.8        4.7        0.78301226]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 23:
# [6.1        2.8        3.32693379 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 24:
# [6.1        2.8        1.93890029 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 25:
# [6.1        2.8        4.7        2.03546472]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 26:
# [6.1        2.8        4.7        0.49582905]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 27:
# [6.1        4.01484541 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 28:
# [6.1        2.8        4.7        2.19443033]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 29:
# [6.1        2.8        5.64673778 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 30:
# [6.1        3.13037257 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 31:
# [6.1        2.8        1.28835977 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 32:
# [6.1        2.8        1.21770235 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 33:
# [5.58475765 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 34:
# [6.1        4.09126695 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 35:
# [6.1        2.8        4.7        0.93053764]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 36:
# [6.1        2.8        6.65403593 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 37:
# [6.1        2.8        5.91170599 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 38:
# [6.1        2.8        5.35380394 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 39:
# [6.1        2.8        4.7        2.41992738]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 40:
# [6.1        2.8        4.7        1.77904677]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 41:
# [6.1        2.8        1.84719397 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 42:
# [5.93757925 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 43:
# [6.1        2.8        1.51790586 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 44:
# [6.1        2.8        4.7        0.51318047]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 45:
# [4.30579502 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 46:
# [6.1        2.8        3.23559194 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 47:
# [6.1        2.8        4.08112127 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 48:
# [6.1       2.8       5.4290329 1.2      ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 49:
# [4.34074168 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 50:
# [6.1        2.8        5.95501856 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 51:
# [6.1        4.32864755 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 52:
# [7.63447239 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 53:
# [6.1        2.8        1.13787301 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 54:
# [6.1        2.8        4.7        2.43800837]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 55:
# [6.1        2.8        4.7        2.46221998]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 56:
# [4.69481106 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 57:
# [6.1        2.8        4.7        2.09475513]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 58:
# [6.1      2.8      5.851043 1.2     ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 59:
# [6.1        2.8        4.7        2.39451594]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 60:
# [6.1        2.8        4.7        2.30807809]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 61:
# [6.1        2.8        6.16923505 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 62:
# [4.55650497 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 63:
# [6.1        2.56882431 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 64:
# [6.1        2.8        6.59010813 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 65:
# [6.1        2.8        4.7        2.49224279]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 66:
# [6.1        2.8        4.7        2.26765447]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 67:
# [6.1        2.21818673 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 68:
# [6.1        2.8        2.88424197 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 69:
# [6.1        2.8        4.7        1.28231493]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 70:
# [6.1        2.8        4.7        2.27183475]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 71:
# [6.1        2.8        4.7        0.70676033]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 72:
# [6.1        3.88277146 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 73:
# [6.1        2.8        4.7        2.41562685]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 74:
# [4.66993782 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 75:
# [6.1        3.88366159 4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 1
# Correctly classified: True
#
# Mutant 76:
# [5.64422798 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 77:
# [6.1        2.8        4.7        0.41154757]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 78:
# [6.1        2.8        1.73643899 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 79:
# [6.1        2.8        4.7        1.68889804]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 80:
# [6.1       2.8       1.9784421 1.2      ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 81:
# [6.1        2.8        5.65944641 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 82:
# [6.1        2.8        1.39659942 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 83:
# [6.1        2.8        2.81452822 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 84:
# [6.1        2.8        6.11683031 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 85:
# [6.91765883 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 86:
# [6.1        2.8        1.97914486 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 87:
# [5.41228454 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 88:
# [6.1        2.8        1.29666545 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 89:
# [6.1        2.8        2.67314875 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 90:
# [5.27077855 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 91:
# [6.1        2.8        4.7        1.22120272]
# Predicted class: 1 (versicolor)
# Changed feature: 3
# Correctly classified: True
#
# Mutant 92:
# [6.1        2.8        6.20428941 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 93:
# [6.1        2.8        1.65929017 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 94:
# [6.1        2.8        3.44241469 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 95:
# [6.1        2.8        4.7        1.95543908]
# Predicted class: 2 (virginica)
# Changed feature: 3
# Correctly classified: False
#
# Mutant 96:
# [6.1        2.8        3.86629265 1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 2
# Correctly classified: True
#
# Mutant 97:
# [5.28082095 2.8        4.7        1.2       ]
# Predicted class: 1 (versicolor)
# Changed feature: 0
# Correctly classified: True
#
# Mutant 98:
# [6.1        2.8        1.55556658 1.2       ]
# Predicted class: 0 (setosa)
# Changed feature: 2
# Correctly classified: False
#
# Mutant 99:
# [6.1        2.8        5.56426252 1.2       ]
# Predicted class: 2 (virginica)
# Changed feature: 2
# Correctly classified: False
#
#
# Prediction distribution for Test_Suit:
# Class 0 (setosa): 15 mutants
# Class 1 (versicolor): 50 mutants
# Class 2 (virginica): 35 mutants
#
# Correctly classified mutants in Test_Suit: 50
# Incorrectly classified mutants in Test_Suit: 50
#
# Class name mapping:
# Class 0: setosa
# Class 1: versicolor
# Class 2: virginica
#
# Feature names:
# Feature 0: sepal length (cm)
# Feature 1: sepal width (cm)
# Feature 2: petal length (cm)
# Feature 3: petal width (cm)

# %%
def calculate_feature_relevance(Test_Suit, sample_original, clf):
    n_features = len(sample_original)
    Et = np.zeros(n_features)
    Ef = np.zeros(n_features)
    Nt = np.zeros(n_features)
    Nf = np.zeros(n_features)

    original_prediction = clf.predict([sample_original])[0]

    for mutant in Test_Suit:
        mutant_prediction = clf.predict([mutant])[0]
        for feature in range(n_features):
            if mutant[feature] == sample_original[feature]:
                if mutant_prediction == original_prediction:
                    Et[feature] += 1
                else:
                    Ef[feature] += 1
            else:
                if mutant_prediction == original_prediction:
                    Nt[feature] += 1
                else:
                    Nf[feature] += 1

    return Et, Ef, Nt, Nf

# Calculate feature relevance
Et, Ef, Nt, Nf = calculate_feature_relevance(Test_Suit, sample_original, clf)

# %%
# Calculate Wong1 feature importance
def calculate_ochiai(Ef, Ep, Nf, Np):
    numerator = Ef
    denominator = np.sqrt((Ef + Nf) * (Ef + Ep))
    return np.divide(numerator, denominator, where=denominator!=0)

def calculate_tarantula(Ef, Ep, Nf, Np):
    numerator = np.divide(Ef, Ef + Nf, where=(Ef + Nf)!=0)
    denominator = numerator + np.divide(Ep, Ep + Np, where=(Ep + Np)!=0)
    return np.divide(numerator, denominator, where=denominator!=0)

def calculate_zoltar(Ef, Ep, Nf, Np):
    epsilon = 1e-10  # Small value to prevent division by zero
    return Ef / (Ef + Nf + Ep + (10000 * Nf * Ep / (Ef + epsilon)))

def calculate_wong1(Et, Ef):
    return Et - Ef

formulas = {
    "Wong1": calculate_wong1(Et, Ef),
    "Ochiai": 1- calculate_ochiai(Ef, Et, Nf, Nt),
    "Tarantula": 1- calculate_tarantula(Ef, Et, Nf, Nt),
    "Zoltar": 1- calculate_zoltar(Ef, Et, Nf, Nt)
}


# Normalize scores for each formula
normalized_formulas = {}
for formula_name, scores in formulas.items():
    normalized_scores = (scores - np.min(scores)) / (np.max(scores) - np.min(scores))
    normalized_formulas[f"{formula_name}_normalized"] = normalized_scores

# Combine raw and normalized scores
all_scores = {**formulas, **normalized_formulas}

# Print feature importance for each formula
for formula_name, scores in all_scores.items():
    print(f"\n{formula_name} Feature Importance:")
    for i, feature_name in enumerate(iris.feature_names):
        print(f"{feature_name}: {scores[i]:.4f}")

    # Sort features by importance
    sorted_indices = np.argsort(scores)[::-1]
    print(f"\nFeatures sorted by {formula_name} importance (most to least important):")
    for i in sorted_indices:
        print(f"{iris.feature_names[i]}: {scores[i]:.4f}")

# Prepare the data for plotting
data = [
    {
        "name": iris.feature_names[i],
        **{f"{formula_name}": scores[i] for formula_name, scores in all_scores.items()}
    }
    for i in range(len(iris.feature_names))
]

print("\nData prepared for plotting:")
print(data)
# Out:
# Wong1 Feature Importance:
# sepal length (cm): -16.0000
# sepal width (cm): -11.0000
# petal length (cm): 21.0000
# petal width (cm): 6.0000
#
# Features sorted by Wong1 importance (most to least important):
# petal length (cm): 21.0000
# petal width (cm): 6.0000
# sepal width (cm): -11.0000
# sepal length (cm): -16.0000
#
# Ochiai Feature Importance:
# sepal length (cm): 0.2285
# sepal width (cm): 0.2505
# petal length (cm): 0.6628
# petal width (cm): 0.4591
#
# Features sorted by Ochiai importance (most to least important):
# petal length (cm): 0.6628
# petal width (cm): 0.4591
# sepal width (cm): 0.2505
# sepal length (cm): 0.2285
#
# Tarantula Feature Importance:
# sepal length (cm): 0.4048
# sepal width (cm): 0.4382
# petal length (cm): 0.6842
# petal width (cm): 0.5429
#
# Features sorted by Tarantula importance (most to least important):
# petal length (cm): 0.6842
# petal width (cm): 0.5429
# sepal width (cm): 0.4382
# sepal length (cm): 0.4048
#
# Zoltar Feature Importance:
# sepal length (cm): 0.4048
# sepal width (cm): 0.4382
# petal length (cm): 1.0000
# petal width (cm): 0.9999
#
# Features sorted by Zoltar importance (most to least important):
# petal length (cm): 1.0000
# petal width (cm): 0.9999
# sepal width (cm): 0.4382
# sepal length (cm): 0.4048
#
# Wong1_normalized Feature Importance:
# sepal length (cm): 0.0000
# sepal width (cm): 0.1351
# petal length (cm): 1.0000
# petal width (cm): 0.5946
#
# Features sorted by Wong1_normalized importance (most to least important):
# petal length (cm): 1.0000
# petal width (cm): 0.5946
# sepal width (cm): 0.1351
# sepal length (cm): 0.0000
#
# Ochiai_normalized Feature Importance:
# sepal length (cm): 0.0000
# sepal width (cm): 0.0506
# petal length (cm): 1.0000
# petal width (cm): 0.5310
#
# Features sorted by Ochiai_normalized importance (most to least important):
# petal length (cm): 1.0000
# petal width (cm): 0.5310
# sepal width (cm): 0.0506
# sepal length (cm): 0.0000
#
# Tarantula_normalized Feature Importance:
# sepal length (cm): 0.0000
# sepal width (cm): 0.1197
# petal length (cm): 1.0000
# petal width (cm): 0.4942
#
# Features sorted by Tarantula_normalized importance (most to least important):
# petal length (cm): 1.0000
# petal width (cm): 0.4942
# sepal width (cm): 0.1197
# sepal length (cm): 0.0000
#
# Zoltar_normalized Feature Importance:
# sepal length (cm): 0.0000
# sepal width (cm): 0.0562
# petal length (cm): 1.0000
# petal width (cm): 0.9998
#
# Features sorted by Zoltar_normalized importance (most to least important):
# petal length (cm): 1.0000
# petal width (cm): 0.9998
# sepal width (cm): 0.0562
# sepal length (cm): 0.0000
#
# Data prepared for plotting:
# [{'name': 'sepal length (cm)', 'Wong1': -16.0, 'Ochiai': 0.2284832501895404, 'Tarantula': 0.40476190476190477, 'Zoltar': 0.40476190476190477, 'Wong1_normalized': 0.0, 'Ochiai_normalized': 0.0, 'Tarantula_normalized': 0.0, 'Zoltar_normalized': 0.0}, {'name': 'sepal width (cm)', 'Wong1': -11.0, 'Ochiai': 0.2504683110041386, 'Tarantula': 0.4382022471910112, 'Zoltar': 0.4382022471910112, 'Wong1_normalized': 0.13513513513513514, 'Ochiai_normalized': 0.05061648552146886, 'Tarantula_normalized': 0.11966544062074852, 'Zoltar_normalized': 0.05618222537575976}, {'name': 'petal length (cm)', 'Wong1': 21.0, 'Ochiai': 0.6628291078305901, 'Tarantula': 0.6842105263157896, 'Zoltar': 0.9999740417936734, 'Wong1_normalized': 1.0, 'Ochiai_normalized': 1.0, 'Tarantula_normalized': 1.0, 'Zoltar_normalized': 1.0}, {'name': 'petal width (cm)', 'Wong1': 6.0, 'Ochiai': 0.45910127697374936, 'Tarantula': 0.5428571428571428, 'Zoltar': 0.9998503540063034, 'Wong1_normalized': 0.5945945945945946, 'Ochiai_normalized': 0.5309548202824012, 'Tarantula_normalized': 0.4941704035874436, 'Zoltar_normalized': 0.9997921954549065}]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed
from IPython.display import display

def plot_feature_importance(data, view='Raw', measure='Wong1'):
    fig, ax = plt.subplots(figsize=(14, 8))
    fig.suptitle('Feature Importance Comparison', fontsize=16)

    # Sort data by absolute raw importance of the selected measure
    sorted_data = sorted(data, key=lambda x: abs(x[f'{measure}{"" if view == "Raw" else "_normalized"}']), reverse=True)
    names = [item['name'] for item in sorted_data]
    index = np.arange(len(names))

    # Use coolwarm colormap
    cmap = plt.get_cmap('coolwarm')

    values = [item[f'{measure}{"" if view == "Raw" else "_normalized"}'] for item in sorted_data]
    
    # Create a normalize object for this measure
    if view == 'Raw':
        norm = Normalize(vmin=min(values), vmax=max(values))
    else:
        norm = Normalize(vmin=0, vmax=1)
    
    # Map each value to a color
    colors = [cmap(norm(value)) for value in values]
    
    # Plot the bars
    bars = ax.barh(index, values, 0.8, label=measure, color=colors, alpha=0.7)
    
    # Add a colorbar for this measure
    sm = ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, orientation='vertical', pad=0.02)
    cbar.set_label(f'{measure} Importance', rotation=270, labelpad=15)

    ax.set_yticks(index)
    ax.set_yticklabels(names)
    ax.set_title(f'{view} Importance - {measure}')
    ax.set_xlabel('Importance')

    if view == 'Raw':
        ax.axvline(x=0, color='gray', linestyle='--')
    else:
        ax.set_xlim(0, 1)

    plt.tight_layout()
    plt.show()

# Create interactive widgets
view_widget = widgets.RadioButtons(options=['Raw', 'Normalized'], description='View:')
measure_widget = widgets.RadioButtons(
    options=['Wong1', 'Ochiai', 'Tarantula', 'Zoltar'],
    description='Measure:'
)

# Combine widgets
widgets_combined = widgets.VBox([view_widget, measure_widget])

# Create interactive plot
interactive_plot = interactive(plot_feature_importance,
                               data=fixed(data),
                               view=view_widget,
                               measure=measure_widget)

# Display widgets and plot
display(widgets_combined, interactive_plot.children[-1])
# Out:
# VBox(children=(RadioButtons(description='View:', options=('Raw', 'Normalized'), value='Raw'), RadioButtons(des…
# Output()
