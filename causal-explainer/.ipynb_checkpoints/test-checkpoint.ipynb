# %%
import sys
import os
rise_sfl_path = "/content/RISE-SFL/causal-explainer"  # Replace with the actual path to your RISE-SFL folder
sys.path.append(rise_sfl_path)
from utils.utils import *
# From masker/generation.py
from masker.generation import SFL

import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torchvision import transforms, datasets
import torchvision.models as models
from torch.utils.data import DataLoader
from PIL import Image
import json
from torch.nn.functional import softmax, conv2d
import os
import requests
import zipfile

# %% [markdown]
# Hello broo

# %%
cudnn.benchmark = True
# Load black box model for explanations
model = models.resnet50(True)
model = nn.Sequential(model, nn.Softmax(dim=1))
model = model.eval()
model = model.cuda()

for p in model.parameters():
    p.requires_grad = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cudnn.benchmark = True
#       2 # Load black box model for explanations
#       3 model = models.resnet50(True)
#
# NameError: name 'cudnn' is not defined

# %%
from masker.batch import SFL_batch

input_size = (224,224)
sfl_batch = SFL_batch(model, input_size)
image_folder = r'C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison'
N = 200
s = 8
p1 = 0.2
masks, sampled_tensors, target_list = sfl_batch.generate_batch_images(image_folder, N, s, p1)
# Out:
# Processing images:   0%|          | 0/9 [00:00<?, ?it/s]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\catdog.png
# Processing images:  11%|█         | 1/9 [00:11<01:34, 11.78s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\goldfish.jpg
# Processing images:  22%|██▏       | 2/9 [02:07<08:29, 72.83s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00003169.JPEG
# Processing images:  33%|███▎      | 3/9 [02:14<04:16, 42.76s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00005140.JPEG
# Processing images:  44%|████▍     | 4/9 [02:23<02:27, 29.47s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00021591.JPEG
# Processing images:  56%|█████▌    | 5/9 [02:47<01:50, 27.56s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00024126.JPEG
# Processing images:  67%|██████▋   | 6/9 [03:00<01:07, 22.55s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00027160 copy.JPEG
# Processing images:  78%|███████▊  | 7/9 [03:35<00:53, 26.52s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00030127.JPEG
# Processing images:  89%|████████▉ | 8/9 [05:18<00:50, 50.89s/it]
# C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00039797.JPEG
# Processing images: 100%|██████████| 9/9 [07:07<00:00, 47.46s/it]

# %%
def generate_pass_fail_list(N):
    return ["Pass" if i % 2 == 0 else "Fail" for i in range(N)]

pass_fail_list = generate_pass_fail_list(N)

savepath = 'mask.npy'
mask_array = masks.detach().cpu().numpy()
np.save(savepath, mask_array)

print(masks.shape)
from visuals.plots import SFLVisualizer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 def generate_pass_fail_list(N):
#       2     return ["Pass" if i % 2 == 0 else "Fail" for i in range(N)]
# ----> 4 pass_fail_list = generate_pass_fail_list(N)
#       6 savepath = 'mask.npy'
#       7 mask_array = masks.detach().cpu().numpy()
#
# NameError: name 'N' is not defined

# %%
#If we want to observe any of the images that are being explained, we just need to 
visualizer = SFLVisualizer()
visualizer.interactive_mutant_visualization(sampled_tensors[2], pass_fail_list)
# Out:
# interactive(children=(IntSlider(value=0, description='Mutant Index:', max=199), Output()), _dom_classes=('widg…

# %%
#from sfl_techniques.sfl import RelevanceScore
#A dictionary will be return for the image to be explained
with torch.no_grad():
    output = model(sampled_tensors[0])
    top_probabilities, top_classes = torch.topk(output, k=3, dim=1)
    top_pred_class = top_classes[0][0].item()

for zx in range(3):
    class_name = top_classes[0][zx].item()
    percentage = top_probabilities[0][zx].item() * 100
    print(f'Top {zx+1} class: {class_name}, Probability: {percentage:.2f}%')

confidence_scores = []
for ss in range(N):
    score = top_probabilities[ss][0].item() * 100
    confidence_scores.append(score)
# Out:
# Top 1 class: 243, Probability: 20.27%
# Top 2 class: 676, Probability: 10.82%
# Top 3 class: 246, Probability: 9.48%

# %%
# Initialize list to store confidence scores for each original image
confidence_scores = np.zeros((9, N))

# Process the batch of images
with torch.no_grad():
    for i in range(9):  # For each original image
        for j in range(N):  # For each mutation
            # Extract single image tensor
            single_image = sampled_tensors[i, j].unsqueeze(0)  # Add batch dimension
            
            # Process single image
            output = model(single_image)
            
            # Get top prediction
            top_probability = torch.max(output, dim=1)
            
            # Store confidence score for this mutation
            confidence_scores[i, j] = top_probability.values.item() * 100
            
            # Print top 3 predictions for the first mutation of each original image
            if j == 0:
                top_probabilities, top_classes = torch.topk(output, k=3, dim=1)
                print(f"\nResults for Original Image {i+1}, First Mutation:")
                for k in range(1):
                    class_name = top_classes[0][k].item()
                    percentage = top_probabilities[0][k].item() * 100
                    print(f'Top {k+1} class: {class_name}, Probability: {percentage:.2f}%')
# Out:
# Results for Original Image 1, First Mutation:
# Top 1 class: 243, Probability: 57.36%
#
# Results for Original Image 2, First Mutation:
# Top 1 class: 1, Probability: 62.95%
#
# Results for Original Image 3, First Mutation:
# Top 1 class: 24, Probability: 3.70%
#
# Results for Original Image 4, First Mutation:
# Top 1 class: 874, Probability: 45.86%
#
# Results for Original Image 5, First Mutation:
# Top 1 class: 667, Probability: 17.38%
#
# Results for Original Image 6, First Mutation:
# Top 1 class: 151, Probability: 39.91%
#
# Results for Original Image 7, First Mutation:
# Top 1 class: 4, Probability: 91.73%
#
# Results for Original Image 8, First Mutation:
# Top 1 class: 2, Probability: 41.04%
#
# Results for Original Image 9, First Mutation:
# Top 1 class: 145, Probability: 88.56%

# %%
# For each image, after returning the dictionary, we need to use causal metrics to calculate which one is more efficient
from sfl_techniques.relevance_score import RelevanceScore
relevance_score_calculator = RelevanceScore(device='cuda')

pixel_datasets = []
ochiai_array = []
zoltar_array = []
tarantula_array = []
wong1_array = []
for i in range(9):
    pixel_dataset, ochiai, tarantula, zoltar, wong1 = relevance_score_calculator.run(confidence_scores[i], sampled_tensors[i], masks[i], N)
    pixel_datasets.append(pixel_dataset)
    ochiai_array.append(ochiai)
    zoltar_array.append(zoltar)
    tarantula_array.append(tarantula)
    wong1_array.append(wong1)

# %%
from visuals.saliency_maps.saliency import SaliencyMapVisualizer

# List all files in the directory
all_files = os.listdir(image_folder)

# Filter for .jpg and .png files
image_files = [file for file in all_files if file.lower().endswith(('.jpg', '.png', '.jpeg'))]

saliency_map = SaliencyMapVisualizer(r'C:\Users\eagua\OneDrive\Documents\GitHub\Images\For SHAP comparison\ILSVRC2012_val_00039797.jpeg')
saliency_map.visualize_pixel_scores(pixel_datasets[8],ins='')

# %%
rise_sfl_path = r"C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\metrics-saliency-maps"  # Replace with the actual path to your RISE-SFL folder
sys.path.append(rise_sfl_path)


from saliency_maps_metrics.multi_step_metrics import Deletion, Insertion, compute_correlation, compute_auc_metric
from saliency_maps_metrics.data_replace import select_data_replace_method

deletion_metric = Deletion(data_replace_method="black", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)
insertion_metric = Insertion(data_replace_method="blur", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)

# Set up the path to your RISE-SFL folder
rise_sfl_path = r"C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\RISEX"
sys.path.append(rise_sfl_path)

# %%
from tabulate import tabulate
import torch
import numpy as np
import os
from tqdm import tqdm

device = 'cuda'
model.to(device)


def get_all_image_files(directory):
    image_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                image_files.append(os.path.join(root, file))
    return image_files

# Use the function to get all image files
image_files = get_all_image_files(image_folder)

# Check if there are any image files in the directory
if not image_files:
    print("No image files found in the specified directory or its subdirectories.")
else:
    print(f"Found {len(image_files)} image files.")

    device = 'cuda'
    model.to(device)

# Function to calculate sparsity
def calculate_sparsity(saliency_map):
    max_value = np.max(saliency_map)
    mean_value = np.mean(saliency_map)
    return max_value / mean_value if mean_value != 0 else float('inf')

# Create instances of Deletion and Insertion metrics
deletion_metric = Deletion(data_replace_method="black", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)
insertion_metric = Insertion(data_replace_method="blur", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)

# Initialize dictionary to store cumulative results
cumulative_results = {
    "Wong1": {"DAUC": 0, "DC": 0, "IAUC": 0, "IC": 0, "Sparsity": 0},
    "Tarantula": {"DAUC": 0, "DC": 0, "IAUC": 0, "IC": 0, "Sparsity": 0},
    "Zoltar": {"DAUC": 0, "DC": 0, "IAUC": 0, "IC": 0, "Sparsity": 0},
    "Ochiai": {"DAUC": 0, "DC": 0, "IAUC": 0, "IC": 0, "Sparsity": 0}
}

# Get list of image files
image_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Process each image
for i, (image_file, target_class) in enumerate(zip(image_files, target_list)):
    image_path = os.path.join(image_folder, image_file)
    img = read_tensor(image_path).to(device)

    # Create a dictionary of saliency maps for this image
    saliency_maps = {
        "Wong1": wong1_array[i][0],
        "Tarantula": tarantula_array[i][0],
        "Zoltar": zoltar_array[i][0],
        "Ochiai": ochiai_array[i][0]
    }

    # Process each saliency map for this image
    for name, saliency_map in saliency_maps.items():
        saliency_map_tensor = torch.from_numpy(saliency_map).float().unsqueeze(0).unsqueeze(0).to(device)

        # Compute Deletion metrics
        deletion_result = deletion_metric(model, img, saliency_map_tensor, class_to_explain_list=[target_class])
        cumulative_results[name]["DAUC"] += deletion_result["dauc"]
        cumulative_results[name]["DC"] += deletion_result["dc"]

        # Compute Insertion metrics
        insertion_result = insertion_metric(model, img, saliency_map_tensor, class_to_explain_list=[target_class])
        cumulative_results[name]["IAUC"] += insertion_result["iauc"]
        cumulative_results[name]["IC"] += insertion_result["ic"]

        # Calculate sparsity
        cumulative_results[name]["Sparsity"] += calculate_sparsity(saliency_map)

# Calculate averages
num_images = len(image_files)
results = []
for name, metrics in cumulative_results.items():
    avg_metrics = [name] + [metrics[key] / num_images for key in ["DAUC", "DC", "IAUC", "IC", "Sparsity"]]
    results.append(avg_metrics)

# Create a table using tabulate
headers = ["Saliency Map", "Avg DAUC", "Avg DC", "Avg IAUC", "Avg IC", "Avg Sparsity"]
table = tabulate(results, headers=headers, tablefmt="grid", floatfmt=".4f")

# Print the table
print(f"Average Metrics for {num_images} images:")
print(table)
# Out:
# Found 22 image files.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 38
#      35     return max_value / mean_value if mean_value != 0 else float('inf')
#      37 # Create instances of Deletion and Insertion metrics
# ---> 38 deletion_metric = Deletion(data_replace_method="black", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)
#      39 insertion_metric = Insertion(data_replace_method="blur", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)
#      41 # Initialize dictionary to store cumulative results
#
# NameError: name 'Deletion' is not defined

# %%
from tabulate import tabulate
import torch
import numpy as np
import os
from tqdm import tqdm
import math

def analyze_images(image_folder, target_list, model, analysis=False):
    device = 'cuda'
    model.to(device)

    def get_all_image_files(directory):
        image_files = []
        for root, dirs, files in os.walk(directory):
            for file in files:
                if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    image_files.append(os.path.join(root, file))
        return image_files

    # Use the function to get all image files
    image_files = get_all_image_files(image_folder)

    # Check if there are any image files in the directory
    if not image_files:
        print("No image files found in the specified directory or its subdirectories.")
        return

    print(f"Found {len(image_files)} image files.")

    # Function to calculate sparsity
    def calculate_sparsity(saliency_map):
        max_value = np.max(saliency_map)
        mean_value = np.mean(saliency_map)
        return max_value / mean_value if mean_value != 0 else float('inf')

    # Create instances of Deletion and Insertion metrics
    deletion_metric = Deletion(data_replace_method="black", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)
    insertion_metric = Insertion(data_replace_method="blur", bound_max_step=True, batch_size=1, max_step_nb=14*14, cumulative=True)

    # Initialize dictionary to store results for each image
    image_results = {}

    # Process each image with tqdm progress bar
    for i, (image_file, target_class) in tqdm(enumerate(zip(image_files, target_list)), total=len(image_files), desc="Processing images"):
        image_path = os.path.join(image_folder, image_file)
        img = read_tensor(image_path).to(device)

        # Create a dictionary of saliency maps for this image
        saliency_maps = {
            "Wong1": wong1_array[i][0],
            "Tarantula": tarantula_array[i][0],
            "Zoltar": zoltar_array[i][0],
            "Ochiai": ochiai_array[i][0]
        }

        # Initialize results for this image
        image_results[image_file] = {}

        # Process each saliency map for this image
        for name, saliency_map in saliency_maps.items():
            saliency_map_tensor = torch.from_numpy(saliency_map).float().unsqueeze(0).unsqueeze(0).to(device)

            # Compute Deletion metrics
            deletion_result = deletion_metric(model, img, saliency_map_tensor, class_to_explain_list=[target_class])

            # Compute Insertion metrics
            insertion_result = insertion_metric(model, img, saliency_map_tensor, class_to_explain_list=[target_class])

            # Calculate sparsity
            sparsity = calculate_sparsity(saliency_map)

            # Store results for this saliency map
            image_results[image_file][name] = {
                "DAUC": deletion_result["dauc"],
                "DC": deletion_result["dc"],
                "IAUC": insertion_result["iauc"],
                "IC": insertion_result["ic"],
                "Sparsity": sparsity
            }

    # Print individual results if analysis is True
    if analysis:
        for image_file, results in image_results.items():
            print(f"\nMetrics for {image_file}:")
            
            headers = ["Saliency Map", "DAUC", "DC", "IAUC", "IC", "Sparsity"]
            table_data = []
            
            for name, metrics in results.items():
                row = [name] + [f"{metrics[key]:.4f}" for key in ["DAUC", "DC", "IAUC", "IC", "Sparsity"]]
                table_data.append(row)
            
            table = tabulate(table_data, headers=headers, tablefmt="grid")
            print(table)

    # Calculate overall averages and standard deviations
    overall_results = {
        "Wong1": {"DAUC": [], "DC": [], "IAUC": [], "IC": [], "Sparsity": []},
        "Tarantula": {"DAUC": [], "DC": [], "IAUC": [], "IC": [], "Sparsity": []},
        "Zoltar": {"DAUC": [], "DC": [], "IAUC": [], "IC": [], "Sparsity": []},
        "Ochiai": {"DAUC": [], "DC": [], "IAUC": [], "IC": [], "Sparsity": []}
    }

    for image_results in image_results.values():
        for name, metrics in image_results.items():
            for key, value in metrics.items():
                overall_results[name][key].append(value)

    # Create the overall summary table
    print("\nOverall Summary:")
    headers = ["Saliency Map", "Avg DAUC ± Std", "Avg DC ± Std", "Avg IAUC ± Std", "Avg IC ± Std", "Avg Sparsity ± Std"]
    summary_data = []

    for name, metrics in overall_results.items():
        row = [name]
        for key in ["DAUC", "DC", "IAUC", "IC", "Sparsity"]:
            values = metrics[key]
            avg = np.mean(values)
            std = np.std(values)
            row.append(f"{avg:.4f} ± {std:.4f}")
        summary_data.append(row)

    summary_table = tabulate(summary_data, headers=headers, tablefmt="grid")
    print(summary_table)

1000 
# Usage example:
analyze_images(image_folder, target_list, model, analysis=True)  # For individual results and overall summary
#analyze_images(image_folder, target_list, model, analysis=False)  # For overall summary only
# Out:
# Found 22 image files.
# Processing images: 100%|██████████| 22/22 [02:20<00:00,  6.41s/it]
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\catdog.png:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0087 | 0.556  | 0.5715 | 0.1003 |     4.6627 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0085 | 0.4952 | 0.5452 | 0.1182 |     4.0701 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0151 | 0.3088 | 0.6136 | 0.2823 |     1.3529 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.011  | 0.5212 | 0.611  | 0.132  |     3.3105 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\golden-retriever-puppy.jpg:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0573 | 0.3872 | 0.4715 | 0.0646 |     2.5632 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0559 | 0.314  | 0.533  | 0.0847 |     1.9091 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0582 | 0.2552 | 0.3961 | 0.1345 |     1.2021 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0531 | 0.4038 | 0.4699 | 0.0598 |     2.6658 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\goldfish.jpg:
# +----------------+--------+--------+--------+---------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |      IC |   Sparsity |
# +================+========+========+========+=========+============+
# | Wong1          | 0.0525 | 0.3966 | 0.3863 | -0.0309 |     3.7656 |
# +----------------+--------+--------+--------+---------+------------+
# | Tarantula      | 0.1334 | 0.2215 | 0.396  | -0.0332 |     4.7937 |
# +----------------+--------+--------+--------+---------+------------+
# | Zoltar         | 0.0428 | 0.2724 | 0.4201 | -0.0035 |     1.2991 |
# +----------------+--------+--------+--------+---------+------------+
# | Ochiai         | 0.0412 | 0.3212 | 0.4188 | -0.0201 |     4.5631 |
# +----------------+--------+--------+--------+---------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00001209.JPEG:
# +----------------+--------+--------+--------+---------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |      IC |   Sparsity |
# +================+========+========+========+=========+============+
# | Wong1          | 0.0213 | 0.0578 | 0.1382 | -0.0071 |     2.2376 |
# +----------------+--------+--------+--------+---------+------------+
# | Tarantula      | 0.0149 | 0.1283 | 0.2536 |  0.0269 |     2.2749 |
# +----------------+--------+--------+--------+---------+------------+
# | Zoltar         | 0.0315 | 0.042  | 0.2031 |  0.0118 |     1.1933 |
# +----------------+--------+--------+--------+---------+------------+
# | Ochiai         | 0.0355 | 0.0396 | 0.1082 | -0.0186 |     1.9723 |
# +----------------+--------+--------+--------+---------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00003169.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0745 | 0.2425 | 0.8337 | 0.0734 |     4.3293 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0677 | 0.2867 | 0.7258 | 0.0324 |     4.1765 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0801 | 0.2388 | 0.836  | 0.1412 |     1.7665 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.085  | 0.2098 | 0.8366 | 0.0594 |     5.0589 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00005140.JPEG:
# +----------------+--------+--------+--------+---------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |      IC |   Sparsity |
# +================+========+========+========+=========+============+
# | Wong1          | 0.0218 | 0.4636 | 0.5509 | -0.0004 |     5.38   |
# +----------------+--------+--------+--------+---------+------------+
# | Tarantula      | 0.026  | 0.3834 | 0.4866 | -0.0143 |     5.2069 |
# +----------------+--------+--------+--------+---------+------------+
# | Zoltar         | 0.019  | 0.1681 | 0.5444 |  0.0462 |     1.5506 |
# +----------------+--------+--------+--------+---------+------------+
# | Ochiai         | 0.0186 | 0.4503 | 0.5392 | -0.0046 |     6.2214 |
# +----------------+--------+--------+--------+---------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00006505.JPEG:
# +----------------+--------+--------+--------+---------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |      IC |   Sparsity |
# +================+========+========+========+=========+============+
# | Wong1          | 0.0046 | 0.3368 | 0.172  | -0.0018 |     2.6423 |
# +----------------+--------+--------+--------+---------+------------+
# | Tarantula      | 0.0049 | 0.296  | 0.1737 | -0.0032 |     2.4286 |
# +----------------+--------+--------+--------+---------+------------+
# | Zoltar         | 0.0053 | 0.1733 | 0.4378 |  0.0887 |     1.1976 |
# +----------------+--------+--------+--------+---------+------------+
# | Ochiai         | 0.0045 | 0.3263 | 0.2511 |  0.0244 |     2.4502 |
# +----------------+--------+--------+--------+---------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00007455.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0541 | 0.4597 | 0.7515 | 0.0369 |     5.8876 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.059  | 0.408  | 0.7517 | 0.0516 |     6.1851 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0524 | 0.3197 | 0.7362 | 0.1008 |     1.5087 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0511 | 0.4523 | 0.7377 | 0.0283 |     7.0638 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00010495.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0126 | 0.5445 | 0.7041 | 0.2379 |     5.7613 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0121 | 0.6656 | 0.7085 | 0.242  |     5.6291 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0105 | 0.3328 | 0.7154 | 0.2124 |     1.7551 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0106 | 0.6083 | 0.7111 | 0.2128 |     7.2052 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00021056.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.1304 | 0.1481 | 0.8316 | 0.14   |     4.1286 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.176  | 0.0793 | 0.8684 | 0.1987 |     3.9107 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.1316 | 0.1756 | 0.8289 | 0.1588 |     1.6585 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.1255 | 0.1433 | 0.8258 | 0.0982 |     4.3503 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00021591.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0761 | 0.2872 | 0.7637 | 0.0809 |     4.2016 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0783 | 0.2641 | 0.794  | 0.0742 |     4.3213 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0823 | 0.1865 | 0.7528 | 0.1201 |     1.3833 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0849 | 0.2319 | 0.7537 | 0.0466 |     4.6405 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00021821.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0147 | 0.2768 | 0.7112 | 0.0215 |     4.8545 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0145 | 0.2876 | 0.7322 | 0.0338 |     4.0308 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0191 | 0.176  | 0.6731 | 0.0498 |     1.4853 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0187 | 0.2342 | 0.6853 | 0.0207 |     4.4637 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00022112.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0374 | 0.5223 | 0.8804 | 0.2435 |     3.7096 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0379 | 0.4595 | 0.8869 | 0.2433 |     3.3173 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0349 | 0.2471 | 0.8901 | 0.1462 |     1.3611 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0354 | 0.4367 | 0.89   | 0.1842 |     3.426  |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00024126.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0455 | 0.5416 | 0.7496 | 0.0617 |     5.1419 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.042  | 0.5529 | 0.7504 | 0.067  |     4.5185 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0397 | 0.3259 | 0.7658 | 0.1441 |     1.5918 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0395 | 0.5498 | 0.766  | 0.0505 |     5.813  |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00026600.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.172  | 0.3256 | 0.8482 | 0.2608 |     6.1821 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.2095 | 0.3149 | 0.8421 | 0.23   |     6.2758 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.1412 | 0.2107 | 0.8466 | 0.4135 |     1.6601 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.1409 | 0.4113 | 0.8479 | 0.2544 |     6.8996 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00027160 copy.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.3365 | 0.0655 | 0.8708 | 0.1879 |     3.5374 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.3312 | 0.063  | 0.872  | 0.1266 |     4.0649 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.3217 | 0.0492 | 0.8523 | 0.2205 |     1.5116 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.3111 | 0.1118 | 0.8564 | 0.1328 |     4.3432 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00030127.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0483 | 0.5373 | 0.6807 | 0.0296 |     4.276  |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0465 | 0.4385 | 0.6301 | 0.0211 |     4.2915 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.052  | 0.3633 | 0.6752 | 0.0652 |     1.4949 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0515 | 0.5289 | 0.683  | 0.037  |     4.2585 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00035705.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.044  | 0.4364 | 0.9197 | 0.2882 |     5.3167 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0617 | 0.4757 | 0.9135 | 0.2891 |     6.6724 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0441 | 0.2471 | 0.9053 | 0.1718 |     1.5533 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0429 | 0.4818 | 0.9102 | 0.2926 |     6.2554 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00038873.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0139 | 0.6294 | 0.7357 | 0.0477 |     4.5175 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.0142 | 0.7308 | 0.6603 | 0.0358 |     5.8913 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0161 | 0.2427 | 0.6564 | 0.0428 |     1.258  |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0165 | 0.718  | 0.6988 | 0.034  |     5.1608 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00039797.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.2027 | 0.0483 | 0.9493 | 0.3834 |     4.2883 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.2097 | 0.0477 | 0.9532 | 0.4492 |     4.6341 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.1962 | 0.1334 | 0.9368 | 0.1658 |     1.4422 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.1974 | 0.0468 | 0.9357 | 0.2959 |     4.8085 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00047413.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.1342 | 0.2534 | 0.6497 | 0.0157 |     6.7352 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.1171 | 0.2344 | 0.6745 | 0.0256 |     5.5333 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.129  | 0.1543 | 0.6369 | 0.0538 |     1.6878 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.117  | 0.2744 | 0.635  | 0.0096 |     8.5034 |
# +----------------+--------+--------+--------+--------+------------+
#
# Metrics for C:\Users\eagua\OneDrive\Documents\GitHub\6CCS3COV-7CCSMCVI-Computer-Vision\causal-explainer\data_benchmark\ILSVRC2012_val_00048952.JPEG:
# +----------------+--------+--------+--------+--------+------------+
# | Saliency Map   |   DAUC |     DC |   IAUC |     IC |   Sparsity |
# +================+========+========+========+========+============+
# | Wong1          | 0.0653 | 0.2779 | 0.7462 | 0.0872 |     4.5371 |
# +----------------+--------+--------+--------+--------+------------+
# | Tarantula      | 0.066  | 0.3376 | 0.7492 | 0.069  |     5.1077 |
# +----------------+--------+--------+--------+--------+------------+
# | Zoltar         | 0.0728 | 0.2033 | 0.7336 | 0.1428 |     1.6085 |
# +----------------+--------+--------+--------+--------+------------+
# | Ochiai         | 0.0764 | 0.2973 | 0.7363 | 0.0682 |     4.9273 |
# +----------------+--------+--------+--------+--------+------------+
#
# Overall Summary:
# +----------------+------------------+-----------------+------------------+-----------------+----------------------+
# | Saliency Map   | Avg DAUC ± Std   | Avg DC ± Std    | Avg IAUC ± Std   | Avg IC ± Std    | Avg Sparsity ± Std   |
# +================+==================+=================+==================+=================+======================+
# | Wong1          | 0.0740 ± 0.0775  | 0.3543 ± 0.1692 | 0.6780 ± 0.2151  | 0.1055 ± 0.1103 | 4.4844 ± 1.1303      |
# +----------------+------------------+-----------------+------------------+-----------------+----------------------+
# | Tarantula      | 0.0812 ± 0.0818  | 0.3402 ± 0.1773 | 0.6773 ± 0.2026  | 0.1077 ± 0.1171 | 4.5111 ± 1.2511      |
# +----------------+------------------+-----------------+------------------+-----------------+----------------------+
# | Zoltar         | 0.0725 ± 0.0727  | 0.2194 ± 0.0830 | 0.6844 ± 0.1839  | 0.1323 ± 0.0926 | 1.4783 ± 0.1744      |
# +----------------+------------------+-----------------+------------------+-----------------+----------------------+
# | Ochiai         | 0.0713 ± 0.0708  | 0.3545 ± 0.1783 | 0.6776 ± 0.2065  | 0.0908 ± 0.0958 | 4.9255 ± 1.6116      |
# +----------------+------------------+-----------------+------------------+-----------------+----------------------+
